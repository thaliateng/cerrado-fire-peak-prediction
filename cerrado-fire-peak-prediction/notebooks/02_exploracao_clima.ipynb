# %% [markdown]
# # Exploração das séries do INMET
#
# Notebook de narrativa. A lógica reutilizável mora em `src/`; aqui ficam só chamadas e comentários.

# %%
import sys; sys.path.append('..')
from src.config import carregar_params
params = carregar_params()
